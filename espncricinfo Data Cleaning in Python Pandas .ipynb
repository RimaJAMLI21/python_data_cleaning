# %%
import pandas as pd 
import numpy as np

# %%
matches = pd.read_excel(r'C:\Users\OrdiOne\OneDrive\Bureau\Python data analysis projects\espncricinfo.xlsx')
matches
# Out:
#                       Player       Span  Mat  Inns  NO  Runs    HS    Ave  \
# 0           DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94
# 1             HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15
# 2             AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87
# 3            RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97
# 4            GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83
# ..                       ...        ...  ...   ...  ..   ...   ...    ...
# 59          KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26
# 60  Inzamam-ul-Haq (ICC/PAK)  1992-2007  120   200  22  8830   329  49.60
# 61          FMM Worrell (WI)  1948-1963   51    87   9  3860   261  49.48
# 62           SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21
# 63          DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00
#
#        BF     SR  100  50   0    4s  6s
# ...

# %%
#relabel columns
matches = matches.rename(columns={"Mat":"Matches_Played", "Inns":"innings_batted", "NO":"not_outs", "Runs":"runs_scored", "HS":"highest_inns_score", "Ave":"batting_average", "BF":"balls_faced","SR":"batting_strike_rate","100":"100_scored","50":"50_scored","0":"ducks_scored","4s":"boundary_fours","6s":"boundary_sixes"})

# %%
matches
# Out:
#                       Player       Span  Matches_Played  innings_batted  \
# 0           DG Bradman (AUS)  1928-1948              52              80
# 1             HC Brook (ENG)  2022-2023              12              20
# 2             AC Voges (AUS)  2015-2016              20              31
# 3            RG Pollock (SA)  1963-1970              23              41
# 4            GA Headley (WI)  1930-1954              22              40
# ..                       ...        ...             ...             ...
# 59          KD Walters (AUS)  1965-1981              74             125
# 60  Inzamam-ul-Haq (ICC/PAK)  1992-2007             120             200
# 61          FMM Worrell (WI)  1948-1963              51              87
# 62           SJ McCabe (AUS)  1930-1938              39              62
# 63          DR Jardine (ENG)  1928-1934              22              33
#
#     not_outs  runs_scored highest_inns_score  batting_average balls_faced  \
# ...

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player               64 non-null     object
#  1   Span                 64 non-null     object
#  2   Matches_Played       64 non-null     int64
#  3   innings_batted       64 non-null     int64
#  4   not_outs             64 non-null     int64
#  5   runs_scored          64 non-null     int64
#  6   highest_inns_score   64 non-null     object
#  7   batting_average      64 non-null     float64
#  8   balls_faced          61 non-null     object
#  9   batting_strike_rate  61 non-null     float64
#  10  100_scored           64 non-null     int64
#  11  50_scored            64 non-null     int64
#  12  ducks_scored         64 non-null     int64
#  13  boundary_fours       64 non-null     int64
#  14  boundary_sixes       64 non-null     int64
# ...

# %%
matches.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches_Played         False
# innings_batted         False
# not_outs               False
# runs_scored            False
# highest_inns_score     False
# batting_average        False
# balls_faced             True
# batting_strike_rate     True
# 100_scored             False
# 50_scored              False
# ducks_scored           False
# boundary_fours         False
# boundary_sixes         False
# dtype: bool

# %%
matches["balls_faced"].unique()
# Out:
# array(['9800+', 1287, 2667, '1707+', '416+', '6558+', '1288+', '4957+',
#        nan, 17292, '7491+', '4063+', 22882, 2395, '5363+', '2844+', 28903,
#        '178+', 15785, '665+', 1823, '13079+', '108+', '29437+', 7146,
#        19753, '15164+', 31258, 14372, 19375, 22782, '2035+', 10636, 12436,
#        27395, '14184+', 22461, 2764, 14349, 16077, '27002+', 20113,
#        '9613+', 2719, '2731+', 22959, 16345, '488+', '619+', 2445, 15456,
#        '885+', '158+', 11641, '1799+', '8662+', '3217+', '2110+'],
#       dtype=object)

# %%
matches[matches["balls_faced"].isna()==1]
# Out:
#                   Player       Span  Matches_Played  innings_batted  not_outs  \
# 8         ED Weekes (WI)  1948-1958              48              81         5
# 15       CL Walcott (WI)  1948-1960              44              74         7
# 56  Hon.FS Jackson (ENG)  1893-1905              20              33         4
#
#     runs_scored highest_inns_score  batting_average balls_faced  \
# 8          4455                207            58.61         NaN
# 15         3798                220            56.68         NaN
# 56         1415               144*            48.79         NaN
#
#     batting_strike_rate  100_scored  50_scored  ducks_scored  boundary_fours  \
# 8                   NaN          15         19             6             258
# 15                  NaN          15         14             1             107
# 56                  NaN           5          6             3              51
#
#     boundary_sixes
# 8                2
# 15              11
# 56               0

# %%
matches["balls_faced"] = matches["balls_faced"].fillna(0)

# %%
matches["balls_faced"].unique()
# Out:
# array(['9800+', 1287, 2667, '1707+', '416+', '6558+', '1288+', '4957+', 0,
#        17292, '7491+', '4063+', 22882, 2395, '5363+', '2844+', 28903,
#        '178+', 15785, '665+', 1823, '13079+', '108+', '29437+', 7146,
#        19753, '15164+', 31258, 14372, 19375, 22782, '2035+', 10636, 12436,
#        27395, '14184+', 22461, 2764, 14349, 16077, '27002+', 20113,
#        '9613+', 2719, '2731+', 22959, 16345, '488+', '619+', 2445, 15456,
#        '885+', '158+', 11641, '1799+', '8662+', '3217+', '2110+'],
#       dtype=object)

# %%
def convert_balls_faced(balls_faced):
    if isinstance(balls_faced, str):
        return balls_faced.strip('+')
    else:
        return balls_faced
    
matches["balls_faced"] = matches["balls_faced"].apply(convert_balls_faced)

# %%
# Convert 'balls_faced' column from object to int
matches['balls_faced'] = matches['balls_faced'].astype(int)

# %%
matches["balls_faced"].unique()
# Out:
# array([ 9800,  1287,  2667,  1707,   416,  6558,  1288,  4957,     0,
#        17292,  7491,  4063, 22882,  2395,  5363,  2844, 28903,   178,
#        15785,   665,  1823, 13079,   108, 29437,  7146, 19753, 15164,
#        31258, 14372, 19375, 22782,  2035, 10636, 12436, 27395, 14184,
#        22461,  2764, 14349, 16077, 27002, 20113,  9613,  2719,  2731,
#        22959, 16345,   488,   619,  2445, 15456,   885,   158, 11641,
#         1799,  8662,  3217,  2110])

# %%
matches["batting_strike_rate"] = matches["batting_strike_rate"].fillna(0)

# %%
matches["batting_strike_rate"].unique()
# Out:
# array([58.6 , 91.76, 55.68, 54.48, 56.  , 34.59, 45.88, 42.42,  0.  ,
#        53.89, 38.07, 53.58, 54.19, 54.94, 46.22, 39.34, 45.97, 29.21,
#        51.46, 35.48, 59.46, 51.53, 63.88, 54.04, 53.02, 60.51, 45.99,
#        42.51, 52.39, 52.12, 58.72, 44.86, 45.07, 50.13, 43.31, 43.35,
#        48.64, 44.13, 60.1 , 54.51, 41.09, 56.75, 69.77, 51.59, 38.81,
#        51.45, 54.02, 40.16, 30.04, 48.26, 55.92, 37.74, 29.11, 46.92,
#        43.74, 49.16, 60.02, 25.59])

# %%
matches.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches_Played         False
# innings_batted         False
# not_outs               False
# runs_scored            False
# highest_inns_score     False
# batting_average        False
# balls_faced            False
# batting_strike_rate    False
# 100_scored             False
# 50_scored              False
# ducks_scored           False
# boundary_fours         False
# boundary_sixes         False
# dtype: bool

# %%
#drop duplicates 
matches.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 59    False
# 60     True
# 61     True
# 62    False
# 63    False
# Length: 64, dtype: bool

# %%
matches[matches["Player"].duplicated()==1]
# Out:
#                       Player       Span  Matches_Played  innings_batted  \
# 50  Inzamam-ul-Haq (ICC/PAK)  1992-2007             120             200
# 51          FMM Worrell (WI)  1948-1963              51              87
# 60  Inzamam-ul-Haq (ICC/PAK)  1992-2007             120             200
# 61          FMM Worrell (WI)  1948-1963              51              87
#
#     not_outs  runs_scored highest_inns_score  batting_average  balls_faced  \
# 50        22         8830                329            49.60        16345
# 51         9         3860                261            49.48          488
# 60        22         8830                329            49.60        16345
# 61         9         3860                261            49.48          488
#
#     batting_strike_rate  100_scored  50_scored  ducks_scored  boundary_fours  \
# 50                54.02          25         46            15            1105
# ...

# %%
matches= matches.drop_duplicates()
matches[matches["Player"].duplicated()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Matches_Played, innings_batted, not_outs, runs_scored, highest_inns_score, batting_average, balls_faced, batting_strike_rate, 100_scored, 50_scored, ducks_scored, boundary_fours, boundary_sixes]
# Index: []

# %%
matches
# Out:
#                       Player       Span  Matches_Played  innings_batted  \
# 0           DG Bradman (AUS)  1928-1948              52              80
# 1             HC Brook (ENG)  2022-2023              12              20
# 2             AC Voges (AUS)  2015-2016              20              31
# 3            RG Pollock (SA)  1963-1970              23              41
# 4            GA Headley (WI)  1930-1954              22              40
# 5          H Sutcliffe (ENG)  1924-1935              54              84
# 6            E Paynter (ENG)  1931-1939              20              31
# 7        KF Barrington (ENG)  1955-1968              82             131
# 8             ED Weekes (WI)  1948-1958              48              81
# 9            SPD Smith (AUS)  2010-2023             102             181
# 10          WR Hammond (ENG)  1927-1947              85             140
# 11            GS Sobers (WI)  1954-1974              93             160
# ...

# %%
matches["highest_inns_score"].unique()
# Out:
# array([334, 186, '269*', 274, '270*', 194, 243, 256, 207, 239, '336*',
#        '365*', 319, 190, 211, 220, 364, 224, 122, 251, 183, 227, '247*',
#        231, '248*', 215, '400*', '280*', 270, 223, 313, 257, '201*',
#        '232*', 195, '203*', '236*', 200, 201, 380, '278*', 205, 254, 291,
#        278, 374, 329, 261, '182*', '215*', '329*', '144*', '189*', 250,
#        232, 127], dtype=object)

# %%
def convrt_highest_inns_score(highest_inns_score):
    if isinstance(highest_inns_score, str):
        return highest_inns_score.strip('*')
    else:
        return highest_inns_score
    
matches["highest_inns_score"] = matches ["highest_inns_score"].apply(convrt_highest_inns_score)
matches["highest_inns_score"] = matches["highest_inns_score"].astype(int)
# Out:
# C:\Users\OrdiOne\AppData\Local\Temp\ipykernel_3956\2201803902.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches["highest_inns_score"] = matches ["highest_inns_score"].apply(convrt_highest_inns_score)
# C:\Users\OrdiOne\AppData\Local\Temp\ipykernel_3956\2201803902.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches["highest_inns_score"] = matches["highest_inns_score"].astype(int)

# %%
matches["highest_inns_score"].unique()
# Out:
# array([334, 186, 269, 274, 270, 194, 243, 256, 207, 239, 336, 365, 319,
#        190, 211, 220, 364, 224, 122, 251, 183, 227, 247, 231, 248, 215,
#        400, 280, 223, 313, 257, 201, 232, 195, 203, 236, 200, 380, 278,
#        205, 254, 291, 374, 329, 261, 182, 144, 189, 250, 127])

# %%
matches
# Out:
#                       Player       Span  Matches_Played  innings_batted  \
# 0           DG Bradman (AUS)  1928-1948              52              80
# 1             HC Brook (ENG)  2022-2023              12              20
# 2             AC Voges (AUS)  2015-2016              20              31
# 3            RG Pollock (SA)  1963-1970              23              41
# 4            GA Headley (WI)  1930-1954              22              40
# 5          H Sutcliffe (ENG)  1924-1935              54              84
# 6            E Paynter (ENG)  1931-1939              20              31
# 7        KF Barrington (ENG)  1955-1968              82             131
# 8             ED Weekes (WI)  1948-1958              48              81
# 9            SPD Smith (AUS)  2010-2023             102             181
# 10          WR Hammond (ENG)  1927-1947              85             140
# 11            GS Sobers (WI)  1954-1974              93             160
# ...

# %%
#Split up Span into Start and Date

# %%
matches[["Rookie_Year","Final_Year"]] = matches["Span"].str.split("-",1,expand=True)
# Out:
# C:\Users\OrdiOne\AppData\Local\Temp\ipykernel_3956\2285106821.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches[["Rookie_Year","Final_Year"]] = matches["Span"].str.split("-",1,expand=True)
# C:\Users\OrdiOne\AppData\Local\Temp\ipykernel_3956\2285106821.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches[["Rookie_Year","Final_Year"]] = matches["Span"].str.split("-",1,expand=True)

# %%
matches['Rookie_Year'] = matches['Rookie_Year'].astype(int)

# %%
matches['Final_Year'] = matches['Final_Year'].astype(int)

#matches = matches.astype({'Rookie_Year':'int','Final_Year':'int' })

# %%
matches = matches.drop(columns ="Span", inplace=False)

# %%
matches
# Out:
#                       Player  Matches_Played  innings_batted  not_outs  \
# 0           DG Bradman (AUS)              52              80        10
# 1             HC Brook (ENG)              12              20         1
# 2             AC Voges (AUS)              20              31         7
# 3            RG Pollock (SA)              23              41         4
# 4            GA Headley (WI)              22              40         4
# 5          H Sutcliffe (ENG)              54              84         9
# 6            E Paynter (ENG)              20              31         5
# 7        KF Barrington (ENG)              82             131        15
# 8             ED Weekes (WI)              48              81         5
# 9            SPD Smith (AUS)             102             181        22
# 10          WR Hammond (ENG)              85             140        16
# 11            GS Sobers (WI)              93             160        21
# ...

# %%
#split up the country from the player

# %%
matches = matches.drop(columns = 'Coutry', inplace=False)

# %%
matches[['Player', 'Country']] = matches['Player'].str.split('(',2,expand=True)

# %%
matches["Country"] = matches["Country"].str.strip(')')

# %%
matches
# Out:
#                 Player  Matches_Played  innings_batted  not_outs  runs_scored  \
# 0          DG Bradman               52              80        10         6996
# 1            HC Brook               12              20         1         1181
# 2            AC Voges               20              31         7         1485
# 3          RG Pollock               23              41         4         2256
# 4          GA Headley               22              40         4         2190
# 5         H Sutcliffe               54              84         9         4555
# 6           E Paynter               20              31         5         1540
# 7       KF Barrington               82             131        15         6806
# 8           ED Weekes               48              81         5         4455
# 9           SPD Smith              102             181        22         9320
# 10         WR Hammond               85             140        16         7249
# ...

# %%
matches['Country'].unique()
# Out:
# array(['AUS', 'ENG', 'SA', 'WI', 'SL', 'NZ', 'ICC/SA', 'IND', 'ICC/WI',
#        'PAK', 'ICC/IND', 'ZIM', 'ICC/PAK'], dtype=object)

# %%
matches['Player'].unique()
# Out:
# array(['DG Bradman ', 'HC Brook ', 'AC Voges ', 'RG Pollock ',
#        'GA Headley ', 'H Sutcliffe ', 'E Paynter ', 'KF Barrington ',
#        'ED Weekes ', 'SPD Smith ', 'WR Hammond ', 'GS Sobers ',
#        'KC Sangakkara ', 'DJ Mitchell ', 'JB Hobbs ', 'CL Walcott ',
#        'L Hutton ', 'JH Kallis ', 'GE Tyldesley ', 'KS Williamson ',
#        'CA Davis ', 'VG Kambli ', 'GS Chappell ', 'AD Nourse ',
#        'SR Tendulkar ', 'M Labuschagne ', 'BC Lara ', 'Javed Miandad ',
#        'R Dravid ', 'Mohammad Yousuf ', 'Younis Khan ', 'RT Ponting ',
#        'J Ryder ', 'A Flower ', 'MEK Hussey ', 'S Chanderpaul ',
#        'SM Gavaskar ', 'SR Waugh ', 'Abdullah Shafique ', 'ML Hayden ',
#        'AB de Villiers ', 'AR Border ', 'JE Root ', 'IVA Richards ',
#        'DP Conway ', 'DCS Compton ', 'DPMD Jayawardene ',
#        'Inzamam-ul-Haq ', 'FMM Worrell ', 'CP Mead ', 'Abid Ali ',
#        'MJ Clarke ', 'KC Bland ', 'B Mitchell ', 'Hon.FS Jackson ',
# ...

# %%
matches.dtypes
# Out:
# Player                  object
# Matches_Played           int64
# innings_batted           int64
# not_outs                 int64
# runs_scored              int64
# highest_inns_score       int32
# batting_average        float64
# balls_faced              int32
# batting_strike_rate      int32
# 100_scored               int64
# 50_scored                int64
# ducks_scored             int64
# boundary_fours           int64
# boundary_sixes           int64
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
matches["batting_strike_rate"] = matches["batting_strike_rate"].astype(int)

# %%
matches['Career_length'] = matches['Final_Year']-matches['Rookie_Year']
matches
# Out:
#                 Player  Matches_Played  innings_batted  not_outs  runs_scored  \
# 0          DG Bradman               52              80        10         6996
# 1            HC Brook               12              20         1         1181
# 2            AC Voges               20              31         7         1485
# 3          RG Pollock               23              41         4         2256
# 4          GA Headley               22              40         4         2190
# 5         H Sutcliffe               54              84         9         4555
# 6           E Paynter               20              31         5         1540
# 7       KF Barrington               82             131        15         6806
# 8           ED Weekes               48              81         5         4455
# 9           SPD Smith              102             181        22         9320
# 10         WR Hammond               85             140        16         7249
# ...

# %%
#calculation with the dataframe

# %%
#Q1: Cricketers in this dataframe the avrage career length
matches["Career_length"].mean()
# Out:
# 12.833333333333334

# %%
#Q2: AVG batting strike rate for Crickers who played aver 10 years
matches[matches['Career_length'] > 10]["batting_strike_rate"]
# Out:
# 0     58
# 4     56
# 5     34
# 7     42
# 9     53
# 10    38
# 11    53
# 12    54
# 14    46
# 15     0
# 16    39
# 17    45
# 19    51
# 22    51
# 23    63
# 24    54
# 26    60
# 27    45
# 28    42
# 29    52
# 30    52
# 31    58
# 35    43
# 36    43
# 37    48
# 39    60
# 40    54
# 41    41
# 42    56
# 43    69
# 45    38
# 46    51
# 47    54
# 48    40
# 49    30
# 53    55
# 55    29
# 56     0
# 57    46
# 58    43
# 59    49
# Name: batting_strike_rate, dtype: int32

# %%
#Q3 find number of cricketers who played before 1960
matches[matches["Rookie_Year"]< 1960]["Player"].count()
# Out:
# 22

# %%
#Q4: Max Highest Inns score by country
matches.groupby("Country")["innings_batted"].max()
# Out:
# Country
# AUS        287
# ENG        247
# ICC/IND    286
# ICC/PAK    200
# ICC/SA     280
# ICC/WI     232
# IND        329
# NZ         164
# PAK        213
# SA         191
# SL         252
# WI         280
# ZIM        112
# Name: innings_batted, dtype: int64

# %%
matches.groupby("Country")["innings_batted"].max().to_frame("Highinncountry").reset_index().sort_values("Highinncountry", ascending = False)
# Out:
#     Country  Highinncountry
# 6       IND             329
# 0       AUS             287
# 2   ICC/IND             286
# 4    ICC/SA             280
# 11       WI             280
# 10       SL             252
# 1       ENG             247
# 5    ICC/WI             232
# 8       PAK             213
# 3   ICC/PAK             200
# 9        SA             191
# 7        NZ             164
# 12      ZIM             112

# %%
#Q5: 5 Hundreds, fifties, ducks(0) avg by country
Q5 = matches.groupby("Country")["100_scored","50_scored","ducks_scored"].mean()
# Out:
# C:\Users\OrdiOne\AppData\Local\Temp\ipykernel_3956\1222529283.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Q5 = matches.groupby("Country")["100_scored","50_scored","ducks_scored"].mean()

# %%
Q5
# Out:
#          100_scored  50_scored  ducks_scored
# Country
# AUS       21.533333  29.466667      9.000000
# ENG       12.307692  20.769231      4.307692
# ICC/IND   36.000000  63.000000      8.000000
# ICC/PAK   25.000000  46.000000     15.000000
# ICC/SA    45.000000  58.000000     16.000000
# ICC/WI    34.000000  48.000000     17.000000
# IND       29.666667  38.666667      9.666667
# NZ        12.333333  16.333333      4.333333
# PAK       17.800000  23.200000      8.000000
# SA         9.800000  20.200000      3.400000
# SL        28.666667  44.000000     12.333333
# WI        16.625000  25.625000      7.250000
# ZIM       12.000000  27.000000      5.000000

# %%
result = Q5.sort_values(by=["100_scored", "50_scored", "ducks_scored"], ascending=False)
result
# Out:
#          100_scored  50_scored  ducks_scored
# Country
# ICC/SA    45.000000  58.000000     16.000000
# ICC/IND   36.000000  63.000000      8.000000
# ICC/WI    34.000000  48.000000     17.000000
# IND       29.666667  38.666667      9.666667
# SL        28.666667  44.000000     12.333333
# ICC/PAK   25.000000  46.000000     15.000000
# AUS       21.533333  29.466667      9.000000
# PAK       17.800000  23.200000      8.000000
# WI        16.625000  25.625000      7.250000
# NZ        12.333333  16.333333      4.333333
# ENG       12.307692  20.769231      4.307692
# ZIM       12.000000  27.000000      5.000000
# SA         9.800000  20.200000      3.400000
